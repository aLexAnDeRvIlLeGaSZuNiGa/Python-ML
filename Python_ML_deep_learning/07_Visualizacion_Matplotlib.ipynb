# %% [markdown]
# # Visualización con Matplotlib
#
# Importar las librerías necesarias

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# <b>interfaz Pyplot</b>
#
#
#  + Permite llevar a cabo la función plot: listas, arrays
#  + Personalizar las lineas, colores, leyendas, etc.
#  + Ofrece un conjunto de tipos de graficas: hist(), scatter(), boxplot(), etc
#  + Indentificar los componentes:
#       + Datos: Listas, ndarray, Pandas Series
#       + Elementos: Titulos, nombre de los ejes, etc. Se accede a los elementos básicos con <b>.plt</b>
#  + markers: https://matplotlib.org/api/markers_api.html
#  + leyenda: https://matplotlib.org/api/_as_gen/matplotlib.pyplot.legend.html
#  + Colores: https://matplotlib.org/api/colors_api.html
#  + Estilos: https://tonysyu.github.io/raw_content/matplotlib-style-gallery/gallery.html

# %% [markdown]
# ### 1.Gráfico de línea
#
# Caso 1:
#   + Datos: Listas
#   + Representación: Una línea con los puntos de cada lista

# %%
# Un gráfico de línea
a = [1, 2, 3, 4]
b = [11, 22, 33, 44]

plt.plot(a, b)
plt.show()

# %%
# ?plt.plot

# %%
plt.plot(a, b, 'ro')
plt.show()

# %%
plt.plot(a, b, 'ro')
plt.axis([0, 6, 0, 60]) # especifica la ventana gráfica de los ejes. [xmin, xmax, ymin, ymax]
plt.show()

# %%
# Un gráfico de línea
a = [1, 2, 3, 4]
b = [11, 22, 33, 44]

plt.plot(a, b, color='red', linewidth=2, label='línea')
plt.legend()
plt.show()

# %% [markdown]
# ### Markers
#
# ![matplotlib_1%20-%20copia.jpeg](attachment:matplotlib_1%20-%20copia.jpeg)

# %% [markdown]
# ![matplotlib2.jpg%20-%20copia.jpeg](attachment:matplotlib2.jpg%20-%20copia.jpeg)

# %% [markdown]
# |![matplotlib3.jpg%20-%20copia.jpeg](attachment:matplotlib3.jpg%20-%20copia.jpeg)

# %% [markdown]
# ![matplotlib4%20-%20copia.jpeg](attachment:matplotlib4%20-%20copia.jpeg)

# %%
plt.plot([0, 0.1, 0.2, 0.5, 0.6],
         [1, -1, 0, 3, -1],
          marker = 'o',
          linestyle= '--')
plt.show()

# %%
plt.plot(np.array([0, 0.1, 0.2, 0.5, 0.6]),
         np.array([1, -1, 0, 3, -1]),
          marker = 'o',
          linestyle= '--')
plt.show()

# %%
plt.plot(a, b, color='g', marker='d', linestyle='dashed', linewidth=4, label="línea", markersize=15)
plt.legend()
plt.show()

# %% [markdown]
# Caso 2
#
#  + Datos: Array
#  + Representación: Una función en un solo sistema de ejes

# %%
x=np.linspace(-1,5,20)

# %%
x
# Out:
# array([-1.        , -0.68421053, -0.36842105, -0.05263158,  0.26315789,
#         0.57894737,  0.89473684,  1.21052632,  1.52631579,  1.84210526,
#         2.15789474,  2.47368421,  2.78947368,  3.10526316,  3.42105263,
#         3.73684211,  4.05263158,  4.36842105,  4.68421053,  5.        ])

# %%
# Calculando la función a los valores de objeto x 
f(x)
# Out:
# array([ 2.71828183e+00, -7.96243209e-01, -9.78977001e-01,  9.96930381e-01,
#        -6.34721800e-02, -4.92934522e-01,  3.22533675e-01,  7.31645866e-02,
#        -2.14370737e-01,  8.66822176e-02,  6.32097958e-02, -8.31244191e-02,
#         1.50859545e-02,  3.53635360e-02, -2.87394599e-02, -1.96780260e-03,
#         1.64350752e-02, -8.58199192e-03, -3.71167637e-03,  6.73794700e-03])

# %%
# ?plt.axis

# %%
# Elementos: .plt()
# Representando un solo gráfico

plt.figure(figsize = (10,5)) # Aumentar el tamaño de la ventana
plt.title("Grafica de la funcion f(x)")
plt.xlabel("Eje X")
plt.ylabel("Eje Y")
plt.axis((-1,5,-0.5,2)) # xmin, xmax, ymin, ymax = axis()
plt.plot(x,f(x),
         marker = 'o',
        linewidth = 6, #Aumentar el tamaño de la línea 
         markersize=15, #Aumenta el tamaño de los puntos
        color = 'r', 
        alpha = 0.8, #Tonalidad de la línea 
        linestyle = '--',
        label = 'f(x)')
plt.legend()
plt.show()

# %%
# Otro ejemplo 
npoints = 100

X = np.random.randn(npoints)
Y = -0.4 * X
plt.plot(X,Y, label ="otra linea")
plt.grid() #agrega cuadrículas al gráfico
plt.legend()
plt.show()

# %% [markdown]
# Caso 3
#
#    + Datos: Array
#    + Representar: Dos gráficos en un mismo sistema de Ejes

# %%
x=np.linspace(-1,5,20)

# %%
def fCuadratica(x):
    return x**2

def fCubica(x): 
    return x**3

# %%
plt.figure(figsize=(10,5))
plt.title("Mis gráficos")
plt.xlabel("Eje x")
plt.ylabel("Eje y")
plt.plot(x,fCuadratica(x),
         #marker = '*',
         #color = 'b',
         #linestyle= '-',
         '*b-',
         label = 'F(x)**2'
         )
plt.plot(x,fCubica(x),
         #marker = 'o'
         #color = 'k',
         #linestyle = '--',
         'ok--',
         label ='F(x)**3')
plt.legend(loc =  'best')
plt.show()

# %%
with  plt.style.context('dark_background'):
     plt.plot(np.sin(np.linspace(0, 2 * np.pi)), 'r-o')
plt.show()

# %%
with plt.style.context('dark_background'):
    plt.plot(np.sin(np.linspace(0, 2 * np.pi)), 'r-o')
plt.axis([0, 10, 0, 10]) # permite tener un entorno del mismo tamaño de ambos ejes
plt.show()

# %% [markdown]
# Para otros tipos de estilos: https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html

# %% [markdown]
# ## 2. Histograma
#
# Los histogramas representan en altura la acumulación de caso en intervalos de valor. Son apropiados para variables cuantitativas.

# %%
data_normal_1 = np.random.normal(loc = 1.0, scale = 0.5, size = 1000)

# loc: Valor "float", representa el centro de la distribución
# scale: Valor "float", representa la desviación Estandar de la distrib.
# size: un valor "int"

# %%
print(data_normal_1.shape)
print(data_normal_1.dtype)
print(data_normal_1[0:30])
# Out:
# (1000,)
# float64
# [0.64536286 1.20216814 1.11222591 0.91485391 0.82440103 1.05652951
#  1.04044455 0.78577638 1.10000088 1.51397031 0.16785334 0.86942268
#  0.72251668 0.90623581 0.48677689 0.43586297 1.46623497 1.52152964
#  1.23792948 0.5045708  1.71634131 1.24969856 0.41770028 0.0263295
#  0.07819056 1.1431877  1.09736817 0.57328477 0.69497223 1.00027395]

# %%
plt.title("Histograma")
plt.xlabel("Valor")
plt.ylabel("Frecuencia")
plt.hist(data_normal_1,
         bins=40, 
         alpha = 0.6,
         edgecolor = 'red',
         label = "histograma Data 1")
# bins: numero de Intervalos de clase 
# alpha: Nitidez -[0-1]
plt.legend()
plt.show()

# %% [markdown]
# Podemos agregar texto usando <b>plt.text()</b>

# %%
Num_puntos = 1000
mu = 10 #media of distribution
sigma = 10 # desviación estándar
x = mu + sigma * np.random.randn(Num_puntos) #genera Num_puntos puntos aleatorios de media mu y desviación tipica sigma.

plt.hist(x, bins=20, color= 'skyblue', edgecolor='white')
plt.text(-15, 120, r'$\mu=10,\ \sigma=10$')
plt.title('Histograma ede IQ')
plt.grid(True) #agrega una tram a de cuadriculas
plt.show()

# %%
data_normal_2 = np.random.normal(loc = 1.5, scale = 0.1, size = 500)
data_normal_3 = np.random.normal(loc = 0.5, scale = 0.6, size = 500)

# %%
plt.figure(figsize = (8,5))
plt.title("Histograma")
plt.xlabel("Eje X")
plt.ylabel("Eje Y")
plt.hist(data_normal_2,bins = 20, alpha = 0.5, edgecolor = 'k', label = 'Hist N2')
plt.hist(data_normal_3,bins = 20,alpha = 0.5, edgecolor = 'k', label = 'Hist N3')
plt.legend()
plt.show()

# %% [markdown]
# ## 3. Boxplot

# %%
# Cargar un dataset

import pandas as pd 
import numpy as np
from sklearn.datasets import fetch_california_housing
housing = fetch_california_housing()
import matplotlib.pyplot as plt

# %%
#Creación de un objeto
california = fetch_california_housing()

# %%
# Carga de los datos
X=california.data

# %%
# Carga del target
y=california.target

# %%
X.shape
# Out:
# (20640, 8)

# %%
y.shape
# Out:
# (20640,)

# %%
dfCalifornia=pd.DataFrame(data = X)

# %%
dfCalifornia.head(5)
# Out:
#         0     1         2         3       4         5      6       7
# 0  8.3252  41.0  6.984127  1.023810   322.0  2.555556  37.88 -122.23
# 1  8.3014  21.0  6.238137  0.971880  2401.0  2.109842  37.86 -122.22
# 2  7.2574  52.0  8.288136  1.073446   496.0  2.802260  37.85 -122.24
# 3  5.6431  52.0  5.817352  1.073059   558.0  2.547945  37.85 -122.25
# 4  3.8462  52.0  6.281853  1.081081   565.0  2.181467  37.85 -122.25

# %%
dfCalifornia.columns = list(california.feature_names)

# %%
dfCalifornia.head(10)
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# 5  4.0368      52.0  4.761658   1.103627       413.0  2.139896     37.85
# 6  3.6591      52.0  4.931907   0.951362      1094.0  2.128405     37.84
# 7  3.1200      52.0  4.797527   1.061824      1157.0  1.788253     37.84
# 8  2.0804      42.0  4.294118   1.117647      1206.0  2.026891     37.84
# 9  3.6912      52.0  4.970588   0.990196      1551.0  2.172269     37.84
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25
# 5    -122.25
# 6    -122.25
# 7    -122.25
# 8    -122.26
# 9    -122.25

# %%
# Unir con el target
dfCalifornia['Target'] = y

# %%
dfCalifornia.head(5)
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  Target
# 0    -122.23   4.526
# 1    -122.22   3.585
# 2    -122.24   3.521
# 3    -122.25   3.413
# 4    -122.25   3.422

# %%
plt.title("Boxplot de California DataFrame")
plt.boxplot(dfCalifornia['Target'])
plt.show()
dfCalifornia['Target'].describe()
# Out:
# count    20640.000000
# mean         2.068558
# std          1.153956
# min          0.149990
# 25%          1.196000
# 50%          1.797000
# 75%          2.647250
# max          5.000010
# Name: Target, dtype: float64

# %%
plt.figure(figsize = (5,3))
plt.title("Boxplot")
plt.xlabel("Eje X")
plt.ylabel("Eje Y")
#plt.boxplot(dfCalifornia['RM']),flierprops={'markerfacecolor':'g','marker':'s'}
plt.boxplot(dfCalifornia['AveBedrms'], showfliers=False,vert=False)
plt.show()

# %%
dfCalifornia.columns
# Out:
# Index(['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup',
#        'Latitude', 'Longitude', 'Target'],
#       dtype='object')

# %%
var_plot = [dfCalifornia['Longitude'],dfCalifornia['MedInc'],dfCalifornia['Population'],dfCalifornia['Target']]

# %%
plt.boxplot(var_plot)
plt.show()

# %%
dfCalifornia[['Longitude','MedInc','Population','Target']]
# Out:
#        Longitude  MedInc  Population  Target
# 0        -122.23  8.3252       322.0   4.526
# 1        -122.22  8.3014      2401.0   3.585
# 2        -122.24  7.2574       496.0   3.521
# 3        -122.25  5.6431       558.0   3.413
# 4        -122.25  3.8462       565.0   3.422
# ...          ...     ...         ...     ...
# 20635    -121.09  1.5603       845.0   0.781
# 20636    -121.21  2.5568       356.0   0.771
# 20637    -121.22  1.7000      1007.0   0.923
# 20638    -121.32  1.8672       741.0   0.847
# 20639    -121.24  2.3886      1387.0   0.894
#
# [20640 rows x 4 columns]

# %%
dfCalifornia[['Longitude','MedInc','Population','Target']].describe()
# Out:
#           Longitude        MedInc    Population        Target
# count  20640.000000  20640.000000  20640.000000  20640.000000
# mean    -119.569704      3.870671   1425.476744      2.068558
# std        2.003532      1.899822   1132.462122      1.153956
# min     -124.350000      0.499900      3.000000      0.149990
# 25%     -121.800000      2.563400    787.000000      1.196000
# 50%     -118.490000      3.534800   1166.000000      1.797000
# 75%     -118.010000      4.743250   1725.000000      2.647250
# max     -114.310000     15.000100  35682.000000      5.000010

# %% [markdown]
# ### 4. Diagrama  de barras
#
# Para representar una variable categorica usamos el clasico diagrama de barras. Se representa en alturas cantidades asociadas a categorias de una variable.

# %%
distritos = ['Surco','Miraflores','Barranco','Ate','La Molina','SJM','SJL']

# %%
#Altura 
nro_habitantes = [100,150,65,72,35,45,160]

# %%
#Posicion - index
posicion = list(range(len(distritos)))
posicion
# Out:
# [0, 1, 2, 3, 4, 5, 6]

# %%
print(distritos)
print(nro_habitantes)
print(posicion)
# Out:
# ['Surco', 'Miraflores', 'Barranco', 'Ate', 'La Molina', 'SJM', 'SJL']
# [100, 150, 65, 72, 35, 45, 160]
# [0, 1, 2, 3, 4, 5, 6]

# %%
coorX = [0,1,2,3,4,5,6]
coorY = [100, 150, 65, 72, 35, 45, 160]

# %%
# Te crea una lista de tuplas
list(zip(coorX,coorY))
# Out:
# [(0, 100), (1, 150), (2, 65), (3, 72), (4, 35), (5, 45), (6, 160)]

# %%
plt.bar(x=posicion,
        height = nro_habitantes,
        width=0.6,
        align = 'center',
        color = ['k','r','y','b','g','g','k'],
        edgecolor='k',
        tick_label = distritos)

plt.xticks(posicion, distritos, rotation='vertical')

for x, y in zip(coorX, nro_habitantes):
    plt.text(x,y,s=y,ha ='center',va = 'bottom')
    
plt.show()

# %% [markdown]
# ### Dos variables cuantitativas
#
# ##### Scatter Plot
#
#    + Esta relacionada con dos variables cuantitativas
#    + El grado de asociación lineal que pueden tener dos variables cuantitativas

# %%
dfCalifornia.head(10)
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# 5  4.0368      52.0  4.761658   1.103627       413.0  2.139896     37.85
# 6  3.6591      52.0  4.931907   0.951362      1094.0  2.128405     37.84
# 7  3.1200      52.0  4.797527   1.061824      1157.0  1.788253     37.84
# 8  2.0804      42.0  4.294118   1.117647      1206.0  2.026891     37.84
# 9  3.6912      52.0  4.970588   0.990196      1551.0  2.172269     37.84
#
#    Longitude  Target
# 0    -122.23   4.526
# 1    -122.22   3.585
# 2    -122.24   3.521
# 3    -122.25   3.413
# 4    -122.25   3.422
# 5    -122.25   2.697
# 6    -122.25   2.992
# 7    -122.25   2.414
# 8    -122.26   2.267
# 9    -122.25   2.611

# %%
plt.title("Diagrama de Dispersión")
plt.scatter (dfCalifornia['Population'],dfCalifornia['Target'],alpha =0.6, color= 'g')
plt.xlabel("Population")
plt.ylabel("Target")
plt.show()

# %% [markdown]
#  + Podemos observar una ligera relación inversa en la variable EDAD vs MEDV, esgto significa que a medida que aumenta la edad ligeramente existe una concentración de menores valores de MEDV.

# %% [markdown]
# <b>Realizando otro ejemplo</b>

# %%
datosNormal1 = np.random.normal(loc = 1, scale = 8, size = 500)
datosNormal2 = np.random.normal(loc = 1, scale = 0.5, size = 500)
datosNormal3 = np.random.normal(loc = 1, scale = 2, size = 500)

# %%
plt.figure(figsize=(10,10))
plt.scatter(datosNormal1,datosNormal2,
            marker = '*',
            s = 70,
           alpha = 0.5, color = 'b')
plt.scatter(datosNormal1,datosNormal3,
            marker='o',
            s = 50,
            alpha = 0.5, color = 'r')
plt.show()

# %%
tamaño=np.round(dfCalifornia['Population'].head(100)*20,0)

# %%
plt.figure(figsize=(10,5))
plt.title("Diagrama de dispersión")
plt.xlabel("Population")
plt.ylabel("Target")
plt.scatter(dfCalifornia['Population'].head(100),dfCalifornia['Target'].head(100),
           marker = 'o',
            s =tamaño,
            c = dfCalifornia['Population'].head(100),
           edgecolor='k',
           alpha = 0.5)
plt.axis((0,110,0,60))
plt.show()

# %% [markdown]
# ### 5. Subgráficos en varias secciones

# %%
# ?plt.subplot

# %%
def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)

plt.figure()
plt.subplot(211) #211 : indica la particion del espacio grafico 2 fila 1 columan 1 espacio grafico 
plt.plot(t1, f(t1), 'bo', t2, f(t2), 'k')

plt.subplot(212)
plt.plot(t2, np.cos(2*np.pi*t2), 'r--')
plt.show()

# %%
Num_puntos = 1000
mu = 10 #media of distribution
sigma = 10 #desviación estándar 
x = mu + sigma * np.random.randn(Num_puntos) #genera Num_puntos puntos aleatorios de media mu y desviación típica sigma

# %%
# usando el desempaquetado de tuplas para múltiples ejes
fig, (ax1,ax2) = plt.subplots(2,1)   # divide el espacio gráfico en 2 filas y una columna 

# Preparamos un histograma en el subplot ax 
num_bins = 50 # numero de barras
n, bins, patches = ax1.hist(x, num_bins, density=1,edgecolor='black',color="red")
ax1.set_title('Histograma')

#función de una distribución normal de media mu y desviación típica sigma.
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) * np.exp(-0.5 * (1 / sigma * (bins - mu))**2))

ax2.plot(bins, y,'--',color="green") # mete los valores de las Y y de las X y las dibuja 
ax2.set_xlabel('Gente lista') #configura la leyenda de la grafica
ax2.set_ylabel('Probabilidad')
ax2.set_title('Histograma de CIs: $\mu=100$, $\sigma=15$')

#Ajustar el espaciado para prevenir el recorte de las etiquetas y que no superpongan
fig.tight_layout()
plt.show()

# %%
# usando el desempaquetado de tuplas para múltiples ejes
fig, (ax1,ax2) = plt.subplots(1,2)   #divide el espacio gráfico en 1 fila y 2 columnas

# Preparamos un histograma en el subplot ax 
num_bins = 20 #numeros de barras 
n, bins, patches = ax1.hist(x, num_bins, density=1,edgecolor='black',color="red")
ax1.set_title('Histograma')

#función de una distribución normal de media muy deviación típica sigma. 
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) * np.exp(-0.5 * (1 / sigma * (bins - mu))**2))

ax2.plot(bins, y,'--',color="green") # mete los valores de las Y y las X y las dibuja 
ax2.set_xlabel('Gente lista') #configura la leyenda grafica 
ax2.set_ylabel('Probabilidad')
ax2.set_title('Gráfico línea de CIs: $\mu=100$, $\sigma=15$')

# Ajustar el espaciado para prevenir el recorte de la etiqueta y 
fig.tight_layout() 
plt.show()

# %%
from sklearn.datasets import load_iris
iris = load_iris()

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Libreria para extraer el iris

# %%
pip install pydataset
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pydataset in c:\users\alexander\appdata\roaming\python\python310\site-packages (0.2.0)
# Requirement already satisfied: pandas in c:\programdata\anaconda3\lib\site-packages (from pydataset) (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\programdata\anaconda3\lib\site-packages (from pandas->pydataset) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas->pydataset) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in c:\programdata\anaconda3\lib\site-packages (from pandas->pydataset) (1.23.5)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->pydataset) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from pydataset import data

# %%
iris = data('iris')

# %%
iris.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 1           5.1          3.5           1.4          0.2  setosa
# 2           4.9          3.0           1.4          0.2  setosa
# 3           4.7          3.2           1.3          0.2  setosa
# 4           4.6          3.1           1.5          0.2  setosa
# 5           5.0          3.6           1.4          0.2  setosa

# %%
import matplotlib.pyplot as plt 


s1 = iris['Sepal.Length']
s2 = iris['Petal.Length']
s3 = iris['Sepal.Width']
s4 = iris['Petal.Width']

# usando el desempaquetado de tuplas para múltiples ejes
fig, ((ax1,ax2),(ax3,ax4)) = plt.subplots(2,2,figsize=(8,8))

ax1.boxplot(s1, boxprops=dict(color='blue'))
ax1.set_title('Largo de Sépalo')

ax2.hist(s2, bins=30, density=1,edgecolor='black',color="green")
ax2.set_title("Largo de Pétalo")

ax3.hist(s3, bins=10, density=1,edgecolor='black',color="blue")
ax3.set_title("Ancho de Sépalo")

ax4.plot(s4, '-',color="red")
ax4.set_title("Ancho de Pétalo")

# Ajustar el espaciado para prevenir el recorte de la etiqueta y 
fig.tight_layout()  # también ajustará el espacio entre los subparcelas para minimizar las superposiciones.
plt.show()

# %% [markdown]
# ![WhatsApp%20Image%202023-07-08%20at%204.40.13%20PM.jpeg](attachment:WhatsApp%20Image%202023-07-08%20at%204.40.13%20PM.jpeg)

# %% [markdown]
# ![WhatsApp%20Image%202023-07-08%20at%204.40.48%20PM.jpeg](attachment:WhatsApp%20Image%202023-07-08%20at%204.40.48%20PM.jpeg)

# %% [markdown]
# <b>matplotlib.pyplot</b> admite no solo escalas de eje lineal, sino también escalas logaritmicas y logit. Esto se usa comúnmente  si los datos abarcan muchos ordenes de magnitud. Cambiar la escala de un eje es fácil:
#
# <b>plt.xscale ('log')</b>
#
# A continuación se muestra un ejemplo de cuatro gráficos con los mismos datos y diferentes escalas para el eje y.

# %%
# ?plt.yscale

# %%
from matplotlib.ticker import NullFormatter # useful for `logit` scale
  
# Fixing random state for reproducibility
np.random.seed(19680801)

#make up some data in the interval ]0 , 1[
y = np.random.normal(loc = 0.5, scale=0.4, size=1000)
y = y[(y > 0) & (y < 1)]
y.sort()
x = np.arange(len(y))

# plot with various axes scales
plt.figure(figsize=(8,8)) # podemos definir el tamaño de la figura 

# linear
plt.subplot(221)
plt.plot(x, y)
plt.yscale('linear')
plt.title('linear')
plt.grid(True)

# log
plt.subplot(222)
plt.plot(x, y)
plt.yscale('log')
plt.title('log')
plt.grid(True)

#symmetric log
plt.subplot(223)
plt.plot(x, y - y.mean())
plt.yscale('symlog', linthresh=0.01)
plt.title('symlog')
plt.grid(True)

# logit
plt.subplot(224)
plt.plot(x, y)
plt.yscale('logit')
plt.title('logit')
plt.grid(True)
# Format the minor tick labels of the y-axis into empty strings with
#`NullFormatter`, to avoid cumbering the axis with too many labels.
plt.gca().yaxis.set_minor_formatter(NullFormatter())
# Adjust the subplot layout, because the logit one may take more space
# than usual, due to y-tick labels like "1 - 10^{-3}"
plt.subplots_adjust(top=0.92, bottom=0.08, left=0.10, right=0.95, hspace=0.25,
                    wspace=0.35)

plt.show()

# %% [markdown]
# ###  6. Composición de 2 gráficos

# %%
x = iris['Sepal.Width']
mu = x.mean()
sigma = x.std() 

#Dos gráficos en uno
fig, ax = plt.subplots()

# Preparamos un histograma en el subplot ax 
num_bins = 50 #numero de barras
n, bins, patches = ax.hist(x, num_bins, color = 'g', edgecolor='black')

#función de una distribución normal de media mu y desviación típica sigma.
y = (bins ** 2)

ax.plot(bins, y,'--', color = 'red') #mete los valores de las Y y las X y las dibuja
ax.set_xlabel('Valor de las acciones') #configura la leyenda de la grafica
ax.set_title('Superposición de 2 graficos')

# Ajustar el espaciado para prevenir el recorte de la etiqueta y 
fig.tight_layout()
plt.show()

# %% [markdown]
# ![WhatsApp%20Image%202023-07-08%20at%205.09.27%20PM.jpeg](attachment:WhatsApp%20Image%202023-07-08%20at%205.09.27%20PM.jpeg)

# %% [markdown]
# ![WhatsApp%20Image%202023-07-08%20at%205.10.41%20PM.jpeg](attachment:WhatsApp%20Image%202023-07-08%20at%205.10.41%20PM.jpeg)

# %%
Num_puntos = 1500
mu = 100 #media of distribution 
sigma = 15 #desviación estándar
x = mu + sigma * np.random.randn(Num_puntos) #genera Num_puntos aleatorios de media mu y desviación tipica sigma.

#Dos gráficos en una
fig, ax = plt.subplots()

# Preparamos un histograma en el subplot ax
num_bins = 50 #numeros de barras
n, bins, patches = ax.hist(x, num_bins, density=1,edgecolor='black')

#función de una distribución normal de media mu y desviación tipica sigma.
y = ((1 / (np.sqrt(2 * np.pi)* sigma)) * np.exp(-0.5 * (1 / sigma * (bins - mu))**2))

ax.plot(bins, y,'--') # mete los valores de las Y y las X y las dibuja 
ax.set_xlabel('Gente lista') #configura la leyenda de la grafica 
ax.set_ylabel('Probabilidad')
ax.set_title('Histograma de CIs: $\mu=100$, $\sigma=15$')

# Ajustar el espaciado para prevenir el recorte de la etiqueta y 
fig.tight_layout()
plt.show()

# %% [markdown]
# Más tipos de visualizaciones: https://www.data-to-viz.com/
#
#    Más información: https://matplotlib.org/3.2.1/tutorials/introductory/pyplot.html#sphx-glr-tutorials-introductory-pyplot-py
